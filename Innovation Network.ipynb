# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
cd "/Users/carla/Documents/Analytics"
# Out:
# /Users/carla/Documents/Analytics

# %%
df=pd.read_excel("AIML Proposals.xlsx", sheet_name="Edge list")
df=df.rename(index=str, columns={"Idea Team": "Idea Team1"})

# %%
df=df.loc[:, "Submitter.1":"Idea Team10"]
df['id'] = df.index
df.head()
# Out:
#            Submitter.1              Idea Team1   Idea Team2      Idea Team3  \
# 0      Sonja Davidovic                     NaN          NaN             NaN
# 1  Vladyslav Rashkovan                     NaN          NaN             NaN
# 2    Elena Loukoianova                     NaN          NaN             NaN
# 3    Nikhil Brahmankar                     NaN          NaN             NaN
# 4   Brandon Baker Rice  Nivashini Harikrishnan   Linchun Li   Premela Isaac
#
#   Idea Team4 Idea Team5 Idea Team6 Idea Team7 Idea Team8 Idea Team9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Idea Team10 id
# 0          NaN  0
# 1          NaN  1
# 2          NaN  2
# 3          NaN  3
# ...

# %%
temp=pd.wide_to_long(df, ["Idea Team"], i="id", j="num")
temp2=temp.dropna()
temp.head()
# Out:
#                 Submitter.1               Idea Team
# id num
# 0  1        Sonja Davidovic                     NaN
# 1  1    Vladyslav Rashkovan                     NaN
# 2  1      Elena Loukoianova                     NaN
# 3  1      Nikhil Brahmankar                     NaN
# 4  1     Brandon Baker Rice  Nivashini Harikrishnan

# %%
# %matplotlib notebook

g=nx.from_pandas_edgelist(temp, source='Submitter.1', target='Idea Team',)
nx.draw(g, with_labels=True, font_size=5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
g=nx.from_pandas_edgelist(temp, source='Submitter.1', target='Idea Team')
g2=g.to_undirected()
nx.draw(g2, with_labels=True, node_color='y', font_size=5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

g=nx.from_pandas_edgelist(temp2, source='Submitter.1', target='Idea Team',)
g2=g.to_undirected()
nx.draw(g2, with_labels=True, node_size=7, font_size=5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
